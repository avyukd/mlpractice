# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/avyukd/mlpractice/blob/master/GoogleOpenImage_modelv1.ipynb)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from skimage import io
import urllib
import matplotlib.pyplot as plt
training_dir = "../input/open-image-train"
testing_dir = "../input/test.zip"

# %%
f = urllib.request.urlopen("http://matplotlib.sourceforge.net/_static/logo2.png")
# read the image file in a numpy array
a = plt.imread(f)
plt.imshow(a)
plt.show()
